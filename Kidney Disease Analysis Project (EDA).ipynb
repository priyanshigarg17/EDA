# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("kidney_disease.csv")
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no   no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no   no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no   no  good  no  no         notckd
#
# [5 rows x 26 columns]

# %%
#randomly selecting the particular rows
data.sample(10)
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 330  330  43.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 70    70  61.0   80.0  1.015  0.0  4.0       NaN    normal  notpresent
# 226  226  64.0  100.0  1.015  4.0  2.0  abnormal  abnormal  notpresent
# 123  123  43.0   80.0  1.015  2.0  3.0       NaN  abnormal     present
# 180  180  73.0   90.0  1.010  1.0  4.0  abnormal  abnormal     present
# 38    38  69.0   80.0  1.020  3.0  0.0  abnormal    normal  notpresent
# 280  280  47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 117  117   NaN   70.0  1.020  0.0  0.0       NaN       NaN  notpresent
# 68    68  65.0   70.0  1.010  2.0  0.0       NaN    normal     present
# 340  340  32.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe ane  \
# 330  notpresent  ...   42    NaN  NaN   no   no   no  good   no  no
# ...

# %%
data.shape
# Out:
# (400, 26)

# %%
data.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
data.drop('id', axis=1, inplace = True)

# %%
data
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
data.isnull().sum()
# Out:
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
#data frame has null values -> if the column is numerical then we hace to inpute the null values with the meand median
#where do we use mean --> data which has no outliers
#median --> has outliers

# %%
data.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
#insights from this data
# total count is age column -> 391 (9 null values)

# %%
data.isnull().sum()
# Out:
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['age'].describe()
# Out:
# count    391.000000
# mean      51.483376
# std       17.169714
# min        2.000000
# 25%       42.000000
# 50%       55.000000
# 75%       64.500000
# max       90.000000
# Name: age, dtype: float64

# %%
data.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia','class']

# %%
data['packed_cell_volume'] = pd.to_numeric(data['packed_cell_volume'], errors= 'coerce')

# %%
data['white_blood_cell_count'] = pd.to_numeric(data['white_blood_cell_count'], errors= 'coerce')
data['red_blood_cell_count'] = pd.to_numeric(data['red_blood_cell_count'], errors= 'coerce')

# %%
cat_col = [col for col in data.columns if data[col].dtype == 'object']
num_col = [col for col in data.columns if data[col].dtype != 'object']
num_col
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_col:
  print(f"{col} has {data[col].unique()}")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal']
# pus_cell has ['normal' 'abnormal' nan]
# pus_cell_clumps has ['notpresent' 'present' nan]
# bacteria has ['notpresent' 'present' nan]
# hypertension has ['yes' 'no' nan]
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan]
# coronary_artery_disease has ['no' 'yes' '\tno' nan]
# appetite has ['good' 'poor' nan]
# peda_edema has ['no' 'yes' nan]
# aanemia has ['no' 'yes' nan]
# class has ['ckd' 'ckd\t' 'notckd']

# %%
# Replace unwanted values
data['diabetes_mellitus'].replace(to_replace= {' yes':'yes', '\tyes': 'yes', '\tno':'no'}, inplace=True)
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\3329984969.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['diabetes_mellitus'].replace(to_replace= {' yes':'yes', '\tyes': 'yes', '\tno':'no'}, inplace=True)

# %%
data['coronary_artery_disease'].replace(to_replace= {'\tno':'no'}, inplace=True)
data['class'].replace(to_replace= {'ckd\t':'ckd'}, inplace=True)
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\518904926.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['coronary_artery_disease'].replace(to_replace= {'\tno':'no'}, inplace=True)
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\518904926.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Univariate analysis
# Analysis on the single feature

plt.figure(figsize=(10, 6))
sns.histplot(data['age'], kde=True, bins=20, color='green')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='hypertension', data = data, palette= 'viridis')
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\883358322.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='hypertension', data = data, palette= 'viridis')
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
data['class']=data['class'].map({'ckd':1, 'notckd':0})

# %%
 # Bivariate analysis
  # We basically do analysis on two columns or features

sns.boxplot(x = 'class', y = 'blood_urea', data = data, palette='viridis')
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\1467660384.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'class', y = 'blood_urea', data = data, palette='viridis')
# <Axes: xlabel='class', ylabel='blood_urea'>

# %%
sns.violinplot(x='class', y='specific_gravity', data=data, palette='viridis')
plt.show()
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\2780479077.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='class', y='specific_gravity', data=data, palette='viridis')

# %%
sns.countplot(x='aanemia', data=data, palette='pastel')
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\1966959441.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='aanemia', data=data, palette='pastel')
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
data['appetite'].value_counts().plot.pie(autopct ='%1.1f%%', colors = ['lightcoral', 'lightgreen'], explode = (0,0.1), startangle=90, shadow = True)
plt.show()

# %%
#insights for this -> 20.6 % of the people have poor appetite

# %%
data['white_blood_cell_count'] = pd.to_numeric(data['white_blood_cell_count'], errors= 'coerce')

# %%
sns.histplot(data['white_blood_cell_count'].dropna(), bins = 20, kde = True)
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %%
#most of the data lies between the range of 5000 -10000
#this column is right skewed

# %%
#make a countplot for categorical column
#make a histogram column for numerical column

# %%
data
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
sns.countplot(x='hypertension', data=data, palette='pastel')
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\2050221758.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='hypertension', data=data, palette='pastel')
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
#isnights= people who are suffering from hypertension are 250

# %%
sns.histplot(data['blood_pressure'].dropna(), bins = 20, kde = True)
# Out:
# <Axes: xlabel='blood_pressure', ylabel='Count'>

# %%
#insights = people who

# %%
data['class'].replace(to_replace= {'ckd\t':'ckd'}, inplace=True)
# Out:
# C:\Users\Priyanshi garg\AppData\Local\Temp\ipykernel_26748\191887901.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['class'].replace(to_replace= {'ckd\t':'ckd'}, inplace=True)

# %%
#bivariate analysis
sns.scatterplot(x='age', y='blood_pressure', data = data, hue='class')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
#there is only one person who is having 140 bp whose age is almost 50
#most of the people having bp ranging between 60 to 100
#most of the healthy people lies between bp range of 60-80
#the people who have blood pressure more than 85 have ckd

# %%
#multivariat analysis
#when we take or use more than two features for the analysis
data.corr(numeric_only=True)
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_random    0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
data
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
#heatmap
corr = data.corr(numeric_only=True)
plt.figure(figsize = (18,6))
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# #class and albumin strongly positive correlated (0.63)
# haemoglobin and class strongly negative correlated (-0.77)
# packed cell value and albumin - stronglt negative(-0.61)
# specific gravity and red blood cell count(0.58)
# serum cretanine and sodium (-0.69) negative correlated
# packed cell value and class (-0.74) negative
# blood urea and albumin (0.45) positive
# haemoglobin and albumin (-0.63) negative
# packed cell value and red blood cell count(0.79)
# blood urea and red blood cell count(-0.58)

# %%
data
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
sns.boxplot(x="diabetes_mellitus", y="albumin", data=data)
plt.xlabel('diabetes')
plt.ylabel('alnumin')
# Out:
# Text(0, 0.5, 'alnumin')

# %%
data['albumin'].unique()
# Out:
# array([ 1.,  4.,  2.,  3.,  0., nan,  5.])

# %%
#insights> the people who is having diabetes their albumin range lies between 1 to 3
#insights - the people who dont have diabtes their albumin lies between 0 to 1 but some  exceptions are there
# also 3 and 4 albumin range

# %%
#correlation - strongly positive correlation (x increase y increase)
#neutral correlation 
#negative correlation

# %%
data
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
sns.boxplot(x="aanemia", y='white_blood_cell_count', data=data)
# Out:
# <Axes: xlabel='aanemia', ylabel='white_blood_cell_count'>
